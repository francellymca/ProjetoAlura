# %% [markdown]
# <a href="https://colab.research.google.com/github/francellymca/ProjetoAlura/blob/main/GenAI_conectarPythoncomAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rodando sua IA no Google Colab

# %%
# !pip install -q -U google-genai

# %%
import os
from google.colab import userdata

os.environ['GOOGLE_API_KEY'] = userdata.get('Gemini_API')

# %%
import os
from google.colab import userdata
from google import genai

api_key = userdata.get("Gemini_API")

if not api_key:
    raise ValueError(
        "A chave 'Gemini_API' não foi encontrada nos Secrets do Colab."
    )

client = genai.Client(api_key=api_key)

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model = "gemini-3.5-flash", contents = "O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas, softwares e máquinas capazes de realizar tarefas que, normalmente, exigiriam a **inteligência humana**.
#
# Em termos simples, a IA permite que os computadores "pensem", aprendam, tomem decisões e resolvam problemas de forma autônoma ou semiautônoma.
#
# Aqui está um resumo de como ela funciona, seus tipos e como ela impacta nossas vidas:
#
# ---
#
# ### 1. Como a IA funciona?
# Ao contrário dos programas de computador tradicionais (que seguem regras rígidas escritas por programadores), a IA moderna funciona através do **aprendizado**. Ela analisa grandes volumes de dados, identifica padrões e cria suas próprias regras para tomar decisões.
#
# Os principais pilares da IA hoje são:
# *   **Dados:** O "combustível" da IA. Quanto mais dados ela consome, melhor ela fica.
# *   **Algoritmos:** As instruções matemáticas que processam esses dados.
# ...
